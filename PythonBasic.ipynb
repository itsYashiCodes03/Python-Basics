# %%
age=22
print(type(age))
name ="Asha"
is_student= True
print(type(is_student))
# Out:
# <class 'int'>
# <class 'bool'>

# %%
age=20
if age >=18:
  print("Adult")
# Out:
# Adult

# %%
age=16
if age>=18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Not Eligible

# %%
marks=72
if marks>=90:
    print("A+")
elif marks>=75:
    print("A")
elif marks>=60:
      print("B")
elif marks>=50:
        print("C")
else:
          print("Fail")
# Out:
# B

# %%
age=25
fare=80
if age>=18 and fare>=50:
  print("Condition satisfied")
# Out:
# Condition satisfied

# %%
age =25
survived =1
if age>=18:
  if survived== 1:
    print("Adult survivor")
# Out:
# Adult survivor

# %% [markdown]
# # L**ISTS**
# ordered
# indexed
# mutable
# can contain duplicate value
# # **uses square bracket[]**

# %%
my_list =[]
my_list

[]
# Out:
# []

# %%
ages =[22,38,36,35,35]
names=["Asha","Sachin","Utkarsh"]
mixed =[10,"Python",3.5,True]

# %%
print(ages)
print(names)
print(mixed)
# Out:
# [22, 38, 36, 35, 35]
# ['Asha', 'Sachin', 'Utkarsh']
# [10, 'Python', 3.5, True]

# %%
print(ages[0])
print(ages[-1])
print(names[-1])
print(ages[1:4])
print(ages[1:])
print(ages[:2])
print(ages[::2])
print(mixed[::2])
# Out:
# 22
# 35
# Utkarsh
# [38, 36, 35]
# [38, 36, 35, 35]
# [22, 38]
# [22, 36, 35]
# [10, 3.5]

# %%
print(ages)
ages[2]=27
print(ages)
# Out:
# [22, 38, 27, 35, 35]
# [22, 38, 27, 35, 35]

# %%
print(names)
names.append("Tanvi")
print(names)
# Out:
# ['Asha', 'Sachin', 'Utkarsh']
# ['Asha', 'Sachin', 'Utkarsh', 'Tanvi']

# %%
#insert
names=["Asha","Sachin","Utkarsh"]
names.insert(1,"Yashi")
print(names)
names.insert(0,"Rashi")
print(names)
# Out:
# ['Asha', 'Yashi', 'Sachin', 'Utkarsh']
# ['Rashi', 'Asha', 'Yashi', 'Sachin', 'Utkarsh']

# %%
print(names)
names.extend(["Vansh","Vaibhav"])
# Out:
# ['Rashi', 'Yashi']

# %%
print(names)
# Out:
# ['Rashi', 'Yashi', 'Vansh', 'Vaibhav']

# %%
#removing/deleting items
names.remove("Asha")
print(names)
# Out:
# ['Rashi', 'Yashi', 'Sachin', 'Utkarsh']

# %%
removed=names.pop(2)
print(removed)
print(names)
# Out:
# Sachin
# ['Rashi', 'Yashi']

# %%
print(ages)
del ages[1]
print(ages)
# Out:
# [22, 38, 27, 35, 35]
# [22, 27, 35, 35]

# %%
numbers=[10,20,30]
numbers.clear()
print(numbers)
# Out:
# []

# %%
numbers=[40,10,30,20,10]
print(len(numbers))
# Out:
# 5

# %%
print(numbers.count(10))
# Out:
# 2

# %%
print(numbers)
print(numbers.index(30))
# Out:
# [40, 10, 30, 20, 10]
# 2

# %%
print(numbers)
print(10 in numbers)
# Out:
# [40, 10, 30, 20, 10]
# True

# %%
print(50 in numbers)
# Out:
# False

# %%
print(max(numbers))
# Out:
# 40

# %%
print(min(numbers))
# Out:
# 10

# %%
print(sum(numbers))
# Out:
# 110

# %%
numbers.sort()

# %%
print(numbers)
# Out:
# [10, 10, 20, 30, 40]

# %%
numbers.reverse()
print(numbers)
# Out:
# [40, 30, 20, 10, 10]

# %%
students =[

      ["Tanvi",21,"CSE"],
       ["Utkarsh",22,"CSE"],
       ["Yashi",19,"ECE"]

]

# %%
print(students[0])
# Out:
# ['Tanvi', 21, 'CSE']

# %%
print(students[0][0])
# Out:
# Tanvi

# %%
print(students[2][2])
# Out:
# ECE

# %%
print(students[-1][-1])
# Out:
# ECE

# %%
students[0][1]=22
print(students)
# Out:
# [['Tanvi', 22, 'CSE'], ['Utkarsh', 22, 'CSE'], ['Yashi', 19, 'ECE']]

# %%
students.append(["Sachin",23,"IT"])

# %%
print(students)
# Out:
# [['Tanvi', 22, 'CSE'], ['Utkarsh', 22, 'CSE'], ['Yashi', 19, 'ECE'], ['Sachin', 23, 'IT']]

# %%
for student in students:
  print(student)
# Out:
# ['Tanvi', 22, 'CSE']
# ['Utkarsh', 22, 'CSE']
# ['Yashi', 19, 'ECE']
# ['Sachin', 23, 'IT']

# %%
for value in student:
  print(value)
# Out:
# Sachin
# 23
# IT

# %%
#combining lists with conditions
marks=[35,62,81,45,90]
for mark in marks:
  if mark>=50:
    print(mark,"Pass")
  else:
    print(mark,"Fail")
# Out:
# 35 Fail
# 62 Pass
# 81 Pass
# 45 Fail
# 90 Pass

# %% [markdown]
# # MAKE A **DATAFRAME**

# %%
import pandas as pd
data={
    "Customer":["A1","A2","A3","A4","A5"],
    "Age":[22,35,28,40,55],
    "City":["Delhi","Mathura","Lucknow","Varanasi","Agra"],
    "Amount":[1200,3500,7800,4200,9500],
    "Rating":[4.53,3.5,2,4,5]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Customer  Age      City  Amount  Rating
# 0       A1   22     Delhi    1200    4.53
# 1       A2   35   Mathura    3500    3.50
# 2       A3   28   Lucknow    7800    2.00
# 3       A4   40  Varanasi    4200    4.00
# 4       A5   55      Agra    9500    5.00

# %%
df.loc[0:3,["Customer","City","Amount"]]
# Out:
#   Customer      City  Amount
# 0       A1     Delhi    1200
# 1       A2   Mathura    3500
# 2       A3   Lucknow    7800
# 3       A4  Varanasi    4200

# %%
df.loc[df["Amount"]>5000],["Customer","Amount"]
# Out:
# (  Customer  Age     City  Amount  Rating
#  2       A3   28  Lucknow    7800     2.0
#  4       A5   55     Agra    9500     5.0,
#  ['Customer', 'Amount'])

# %%
#first 5 rows and first 3 columns
df.iloc[0:5,0:3]
# Out:
#   Customer  Age      City
# 0       A1   22     Delhi
# 1       A2   35   Mathura
# 2       A3   28   Lucknow
# 3       A4   40  Varanasi
# 4       A5   55      Agra
